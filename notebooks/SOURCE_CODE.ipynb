# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks

# %%
# For Data Processing
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image, ImageEnhance

# For ML Models
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing.image import load_img

# For Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Miscellaneous
from tqdm import tqdm
import os
import random

# %%
train_dir = r'breastcancerdata/train'
test_dir = r'breastcancerdata/val'

train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir+"//" +label):
        train_paths.append(train_dir + '//'+label+ '//'+image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)

# %%
test_paths = []

test_labels = []

for label in os.listdir(test_dir):
    for image in os.listdir(test_dir+ '//' + label):
        test_paths.append(test_dir +'//'+label + '//'+image)
        test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)

# %%
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    image = ImageEnhance.Brightness(image).enhance(random.uniform(0.8,1.2))
    image = ImageEnhance.Contrast(image).enhance(random.uniform(0.8,1.2))
    image = ImageEnhance.Sharpness(image).enhance(random.uniform(0.8,1.2))
    image = np.array(image)/255.0
    return image

# %%
IMAGE_SIZE = 128


def open_images(paths):

    images = []
    for path in paths:
        image = load_img(path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        image = augment_image(image)
        images.append(image)
    return np.array(images)


images = open_images(train_paths[50:59])
labels = train_labels[50:59]
fig = plt.figure(figsize=(12, 6))
for x in range(1, 9):
    fig.add_subplot(2, 4, x)
    plt.axis('off')
    plt.title(labels[x])
    plt.imshow(images[x])
plt.rcParams.update({'font.size': 12})
plt.show()

# %%
unique_labels = os.listdir(train_dir)

def encode_label(labels):
    encoded = []
    for x in labels:
        encoded.append(unique_labels.index(x))
    return np.array(encoded)

def decode_label(labels):
    decoded = []
    for x in labels:
        decoded.append(unique_labels[x])
    return np.array(decoded)

def datagen(paths, labels, batch_size=12, epochs=1):
    for _ in range(epochs):
        for x in range(0, len(paths), batch_size):
            batch_paths = paths[x:x+batch_size]
            batch_images = open_images(batch_paths)
            batch_labels = labels[x:x+batch_size]
            batch_labels = encode_label(batch_labels)
            yield batch_images, batch_labels

# %%
# Define Dense Block
def dense_block(input_tensor, filters, blocks):
    x = input_tensor
    for i in range(blocks):
        x = dense_unit(x, filters)
    return x

# Define Dense Unit
def dense_unit(input_tensor, filters):
    x = layers.BatchNormalization()(input_tensor)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.Concatenate()([input_tensor, x])
    return x

# Define Transition Block
def transition_block(input_tensor, reduction):
    filters = int(input_tensor.shape[-1] * reduction)
    x = layers.BatchNormalization()(input_tensor)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, 1, padding='same')(x)
    x = layers.AveragePooling2D(2)(x)
    return x

# Define DenseNet model
def DenseNet(input_shape, num_classes, blocks_per_group, growth_rate, reduction):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, 7, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)

    for i, blocks in enumerate(blocks_per_group):
        x = dense_block(x, growth_rate, blocks)
        if i != len(blocks_per_group) - 1:
            x = transition_block(x, reduction)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# %%
# Create DenseNet model
DenseModel = DenseNet(input_shape=(128, 128, 3), num_classes=3, blocks_per_group=[6, 12, 24, 16], growth_rate=32, reduction=0.5)

print(DenseModel.summary())

# Compile the model
DenseModel.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 64)           9472      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 64, 64, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 64, 64, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 64)           0         ['re_lu[0][0]']
#  D)
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)           256       ['max_pooling2d[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 32, 32, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)           18464     ['re_lu_1[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 32, 96)           0         ['max_pooling2d[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 96)           384       ['concatenate[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 32, 32, 96)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)           27680     ['re_lu_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 128)          0         ['concatenate[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 128)          512       ['concatenate_1[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 32, 32, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)           36896     ['re_lu_3[0][0]']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 160)          0         ['concatenate_1[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 160)          640       ['concatenate_2[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 32, 32, 160)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)           46112     ['re_lu_4[0][0]']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 192)          0         ['concatenate_2[0][0]',
#  )                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 192)          768       ['concatenate_3[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 32, 32, 192)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 32)           55328     ['re_lu_5[0][0]']
#
#  concatenate_4 (Concatenate  (None, 32, 32, 224)          0         ['concatenate_3[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 224)          896       ['concatenate_4[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 32, 32, 224)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)           64544     ['re_lu_6[0][0]']
#
#  concatenate_5 (Concatenate  (None, 32, 32, 256)          0         ['concatenate_4[0][0]',
#  )                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 256)          1024      ['concatenate_5[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 32, 32, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          32896     ['re_lu_7[0][0]']
#
#  average_pooling2d (Average  (None, 16, 16, 128)          0         ['conv2d_7[0][0]']
#  Pooling2D)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 128)          512       ['average_pooling2d[0][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 16, 16, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)           36896     ['re_lu_8[0][0]']
#
#  concatenate_6 (Concatenate  (None, 16, 16, 160)          0         ['average_pooling2d[0][0]',
#  )                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 160)          640       ['concatenate_6[0][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 16, 16, 160)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 32)           46112     ['re_lu_9[0][0]']
#
#  concatenate_7 (Concatenate  (None, 16, 16, 192)          0         ['concatenate_6[0][0]',
#  )                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 192)          768       ['concatenate_7[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 16, 16, 192)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 32)           55328     ['re_lu_10[0][0]']
#
#  concatenate_8 (Concatenate  (None, 16, 16, 224)          0         ['concatenate_7[0][0]',
#  )                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 224)          896       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 16, 16, 224)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 32)           64544     ['re_lu_11[0][0]']
#
#  concatenate_9 (Concatenate  (None, 16, 16, 256)          0         ['concatenate_8[0][0]',
#  )                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['concatenate_9[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 16, 16, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 32)           73760     ['re_lu_12[0][0]']
#
#  concatenate_10 (Concatenat  (None, 16, 16, 288)          0         ['concatenate_9[0][0]',
#  e)                                                                  'conv2d_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 288)          1152      ['concatenate_10[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 16, 16, 288)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 32)           82976     ['re_lu_13[0][0]']
#
#  concatenate_11 (Concatenat  (None, 16, 16, 320)          0         ['concatenate_10[0][0]',
#  e)                                                                  'conv2d_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 320)          1280      ['concatenate_11[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 16, 16, 320)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 32)           92192     ['re_lu_14[0][0]']
#  concatenate_12 (Concatenat  (None, 16, 16, 352)          0         ['concatenate_11[0][0]',
#  e)                                                                  'conv2d_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 352)          1408      ['concatenate_12[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 16, 16, 352)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 32)           101408    ['re_lu_15[0][0]']
#
#  concatenate_13 (Concatenat  (None, 16, 16, 384)          0         ['concatenate_12[0][0]',
#  e)                                                                  'conv2d_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 384)          1536      ['concatenate_13[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 16, 16, 384)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 32)           110624    ['re_lu_16[0][0]']
#
#  concatenate_14 (Concatenat  (None, 16, 16, 416)          0         ['concatenate_13[0][0]',
#  e)                                                                  'conv2d_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 16, 16, 416)          1664      ['concatenate_14[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 16, 16, 416)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 32)           119840    ['re_lu_17[0][0]']
#
#  concatenate_15 (Concatenat  (None, 16, 16, 448)          0         ['concatenate_14[0][0]',
#  e)                                                                  'conv2d_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 16, 16, 448)          1792      ['concatenate_15[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 16, 16, 448)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 32)           129056    ['re_lu_18[0][0]']
#
#  concatenate_16 (Concatenat  (None, 16, 16, 480)          0         ['concatenate_15[0][0]',
#  e)                                                                  'conv2d_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 16, 16, 480)          1920      ['concatenate_16[0][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 16, 16, 480)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 32)           138272    ['re_lu_19[0][0]']
#
#  concatenate_17 (Concatenat  (None, 16, 16, 512)          0         ['concatenate_16[0][0]',
#  e)                                                                  'conv2d_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 16, 16, 512)          2048      ['concatenate_17[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 16, 16, 512)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 256)          131328    ['re_lu_20[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 8, 8, 256)            0         ['conv2d_20[0][0]']
#  gePooling2D)
#
#  batch_normalization_21 (Ba  (None, 8, 8, 256)            1024      ['average_pooling2d_1[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 8, 8, 256)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 32)             73760     ['re_lu_21[0][0]']
#
#  concatenate_18 (Concatenat  (None, 8, 8, 288)            0         ['average_pooling2d_1[0][0]',
#  e)                                                                  'conv2d_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 8, 8, 288)            1152      ['concatenate_18[0][0]']
#  tchNormalization)
#  re_lu_22 (ReLU)             (None, 8, 8, 288)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 32)             82976     ['re_lu_22[0][0]']
#
#  concatenate_19 (Concatenat  (None, 8, 8, 320)            0         ['concatenate_18[0][0]',
#  e)                                                                  'conv2d_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 8, 8, 320)            1280      ['concatenate_19[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 8, 8, 320)            0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 32)             92192     ['re_lu_23[0][0]']
#
#  concatenate_20 (Concatenat  (None, 8, 8, 352)            0         ['concatenate_19[0][0]',
#  e)                                                                  'conv2d_23[0][0]']
#
#  batch_normalization_24 (Ba  (None, 8, 8, 352)            1408      ['concatenate_20[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 8, 8, 352)            0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 32)             101408    ['re_lu_24[0][0]']
#
#  concatenate_21 (Concatenat  (None, 8, 8, 384)            0         ['concatenate_20[0][0]',
#  e)                                                                  'conv2d_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 8, 8, 384)            1536      ['concatenate_21[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 8, 8, 384)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 32)             110624    ['re_lu_25[0][0]']
#
#  concatenate_22 (Concatenat  (None, 8, 8, 416)            0         ['concatenate_21[0][0]',
#  e)                                                                  'conv2d_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 8, 8, 416)            1664      ['concatenate_22[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 8, 8, 416)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 32)             119840    ['re_lu_26[0][0]']
#
#  concatenate_23 (Concatenat  (None, 8, 8, 448)            0         ['concatenate_22[0][0]',
#  e)                                                                  'conv2d_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 8, 8, 448)            1792      ['concatenate_23[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 8, 8, 448)            0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 8, 8, 32)             129056    ['re_lu_27[0][0]']
#
#  concatenate_24 (Concatenat  (None, 8, 8, 480)            0         ['concatenate_23[0][0]',
#  e)                                                                  'conv2d_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 8, 8, 480)            1920      ['concatenate_24[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 8, 8, 480)            0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 32)             138272    ['re_lu_28[0][0]']
#
#  concatenate_25 (Concatenat  (None, 8, 8, 512)            0         ['concatenate_24[0][0]',
#  e)                                                                  'conv2d_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 8, 8, 512)            2048      ['concatenate_25[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 8, 8, 512)            0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 32)             147488    ['re_lu_29[0][0]']
#
#  concatenate_26 (Concatenat  (None, 8, 8, 544)            0         ['concatenate_25[0][0]',
#  e)                                                                  'conv2d_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 8, 8, 544)            2176      ['concatenate_26[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 8, 8, 544)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 32)             156704    ['re_lu_30[0][0]']
#
#  concatenate_27 (Concatenat  (None, 8, 8, 576)            0         ['concatenate_26[0][0]',
#  e)                                                                  'conv2d_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 8, 8, 576)            2304      ['concatenate_27[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 8, 8, 576)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 32)             165920    ['re_lu_31[0][0]']
#
#  concatenate_28 (Concatenat  (None, 8, 8, 608)            0         ['concatenate_27[0][0]',
#  e)                                                                  'conv2d_31[0][0]']
#
#  batch_normalization_32 (Ba  (None, 8, 8, 608)            2432      ['concatenate_28[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 8, 8, 608)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 32)             175136    ['re_lu_32[0][0]']
#
#  concatenate_29 (Concatenat  (None, 8, 8, 640)            0         ['concatenate_28[0][0]',
#  e)                                                                  'conv2d_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 8, 8, 640)            2560      ['concatenate_29[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 8, 8, 640)            0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 8, 8, 32)             184352    ['re_lu_33[0][0]']
#
#  concatenate_30 (Concatenat  (None, 8, 8, 672)            0         ['concatenate_29[0][0]',
#  e)                                                                  'conv2d_33[0][0]']
#
#  batch_normalization_34 (Ba  (None, 8, 8, 672)            2688      ['concatenate_30[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 8, 8, 672)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 32)             193568    ['re_lu_34[0][0]']
#
#  concatenate_31 (Concatenat  (None, 8, 8, 704)            0         ['concatenate_30[0][0]',
#  e)                                                                  'conv2d_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 8, 8, 704)            2816      ['concatenate_31[0][0]']
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 8, 8, 704)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 32)             202784    ['re_lu_35[0][0]']
#
#  concatenate_32 (Concatenat  (None, 8, 8, 736)            0         ['concatenate_31[0][0]',
#  e)                                                                  'conv2d_35[0][0]']
#
#  batch_normalization_36 (Ba  (None, 8, 8, 736)            2944      ['concatenate_32[0][0]']
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 8, 8, 736)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 32)             212000    ['re_lu_36[0][0]']
#
#  concatenate_33 (Concatenat  (None, 8, 8, 768)            0         ['concatenate_32[0][0]',
#  e)                                                                  'conv2d_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 8, 8, 768)            3072      ['concatenate_33[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 8, 8, 768)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 8, 8, 32)             221216    ['re_lu_37[0][0]']
#
#  concatenate_34 (Concatenat  (None, 8, 8, 800)            0         ['concatenate_33[0][0]',
#  e)                                                                  'conv2d_37[0][0]']
#
#  batch_normalization_38 (Ba  (None, 8, 8, 800)            3200      ['concatenate_34[0][0]']
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 8, 8, 800)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 32)             230432    ['re_lu_38[0][0]']
#
#  concatenate_35 (Concatenat  (None, 8, 8, 832)            0         ['concatenate_34[0][0]',
#  e)                                                                  'conv2d_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 8, 8, 832)            3328      ['concatenate_35[0][0]']
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 8, 8, 832)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 32)             239648    ['re_lu_39[0][0]']
#
#  concatenate_36 (Concatenat  (None, 8, 8, 864)            0         ['concatenate_35[0][0]',
#  e)                                                                  'conv2d_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 864)            3456      ['concatenate_36[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 8, 8, 864)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 32)             248864    ['re_lu_40[0][0]']
#
#  concatenate_37 (Concatenat  (None, 8, 8, 896)            0         ['concatenate_36[0][0]',
#  e)                                                                  'conv2d_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 8, 8, 896)            3584      ['concatenate_37[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 8, 8, 896)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 32)             258080    ['re_lu_41[0][0]']
#
#  concatenate_38 (Concatenat  (None, 8, 8, 928)            0         ['concatenate_37[0][0]',
#  e)                                                                  'conv2d_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 8, 8, 928)            3712      ['concatenate_38[0][0]']
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 8, 8, 928)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 32)             267296    ['re_lu_42[0][0]']
#
#  concatenate_39 (Concatenat  (None, 8, 8, 960)            0         ['concatenate_38[0][0]',
#  e)                                                                  'conv2d_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 8, 8, 960)            3840      ['concatenate_39[0][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 8, 8, 960)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 32)             276512    ['re_lu_43[0][0]']
#
#  concatenate_40 (Concatenat  (None, 8, 8, 992)            0         ['concatenate_39[0][0]',
#  e)                                                                  'conv2d_43[0][0]']
#
# ...
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 4, 4, 576)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 4, 4, 32)             165920    ['re_lu_48[0][0]']
#
#  concatenate_44 (Concatenat  (None, 4, 4, 608)            0         ['concatenate_43[0][0]',
#  e)                                                                  'conv2d_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 4, 4, 608)            2432      ['concatenate_44[0][0]']
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 4, 4, 608)            0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 4, 4, 32)             175136    ['re_lu_49[0][0]']
#
#  concatenate_45 (Concatenat  (None, 4, 4, 640)            0         ['concatenate_44[0][0]',
#  e)                                                                  'conv2d_49[0][0]']
#
#  batch_normalization_50 (Ba  (None, 4, 4, 640)            2560      ['concatenate_45[0][0]']
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 4, 4, 640)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 4, 4, 32)             184352    ['re_lu_50[0][0]']
#
#  concatenate_46 (Concatenat  (None, 4, 4, 672)            0         ['concatenate_45[0][0]',
#  e)                                                                  'conv2d_50[0][0]']
#
#  batch_normalization_51 (Ba  (None, 4, 4, 672)            2688      ['concatenate_46[0][0]']
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 4, 4, 672)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 4, 4, 32)             193568    ['re_lu_51[0][0]']
#
#  concatenate_47 (Concatenat  (None, 4, 4, 704)            0         ['concatenate_46[0][0]',
#  e)                                                                  'conv2d_51[0][0]']
#
#  batch_normalization_52 (Ba  (None, 4, 4, 704)            2816      ['concatenate_47[0][0]']
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 4, 4, 704)            0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 4, 4, 32)             202784    ['re_lu_52[0][0]']
#
#  concatenate_48 (Concatenat  (None, 4, 4, 736)            0         ['concatenate_47[0][0]',
#  e)                                                                  'conv2d_52[0][0]']
#
#  batch_normalization_53 (Ba  (None, 4, 4, 736)            2944      ['concatenate_48[0][0]']
#  tchNormalization)
#
#  re_lu_53 (ReLU)             (None, 4, 4, 736)            0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 4, 4, 32)             212000    ['re_lu_53[0][0]']
#
#  concatenate_49 (Concatenat  (None, 4, 4, 768)            0         ['concatenate_48[0][0]',
#  e)                                                                  'conv2d_53[0][0]']
#
#  batch_normalization_54 (Ba  (None, 4, 4, 768)            3072      ['concatenate_49[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 4, 4, 768)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 4, 4, 32)             221216    ['re_lu_54[0][0]']
#
#  concatenate_50 (Concatenat  (None, 4, 4, 800)            0         ['concatenate_49[0][0]',
#  e)                                                                  'conv2d_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 4, 4, 800)            3200      ['concatenate_50[0][0]']
#  tchNormalization)
#
#  re_lu_55 (ReLU)             (None, 4, 4, 800)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 4, 4, 32)             230432    ['re_lu_55[0][0]']
#
#  concatenate_51 (Concatenat  (None, 4, 4, 832)            0         ['concatenate_50[0][0]',
#  e)                                                                  'conv2d_55[0][0]']
#
#  batch_normalization_56 (Ba  (None, 4, 4, 832)            3328      ['concatenate_51[0][0]']
#  tchNormalization)
#
#  re_lu_56 (ReLU)             (None, 4, 4, 832)            0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 4, 4, 32)             239648    ['re_lu_56[0][0]']
#
#  concatenate_52 (Concatenat  (None, 4, 4, 864)            0         ['concatenate_51[0][0]',
#  e)                                                                  'conv2d_56[0][0]']
#
#  batch_normalization_57 (Ba  (None, 4, 4, 864)            3456      ['concatenate_52[0][0]']
#  tchNormalization)
#
#  re_lu_57 (ReLU)             (None, 4, 4, 864)            0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 4, 4, 32)             248864    ['re_lu_57[0][0]']
#
#  concatenate_53 (Concatenat  (None, 4, 4, 896)            0         ['concatenate_52[0][0]',
#  e)                                                                  'conv2d_57[0][0]']
#
#  batch_normalization_58 (Ba  (None, 4, 4, 896)            3584      ['concatenate_53[0][0]']
#  tchNormalization)
#
#  re_lu_58 (ReLU)             (None, 4, 4, 896)            0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 4, 4, 32)             258080    ['re_lu_58[0][0]']
#
#  concatenate_54 (Concatenat  (None, 4, 4, 928)            0         ['concatenate_53[0][0]',
#  e)                                                                  'conv2d_58[0][0]']
#
#  batch_normalization_59 (Ba  (None, 4, 4, 928)            3712      ['concatenate_54[0][0]']
#  tchNormalization)
#
#  re_lu_59 (ReLU)             (None, 4, 4, 928)            0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_59 (Conv2D)          (None, 4, 4, 32)             267296    ['re_lu_59[0][0]']
#
#  concatenate_55 (Concatenat  (None, 4, 4, 960)            0         ['concatenate_54[0][0]',
#  e)                                                                  'conv2d_59[0][0]']
#  batch_normalization_60 (Ba  (None, 4, 4, 960)            3840      ['concatenate_55[0][0]']
#  tchNormalization)
#
#  re_lu_60 (ReLU)             (None, 4, 4, 960)            0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 4, 4, 32)             276512    ['re_lu_60[0][0]']
#
#  concatenate_56 (Concatenat  (None, 4, 4, 992)            0         ['concatenate_55[0][0]',
#  e)                                                                  'conv2d_60[0][0]']
#
#  batch_normalization_61 (Ba  (None, 4, 4, 992)            3968      ['concatenate_56[0][0]']
#  tchNormalization)
#
#  re_lu_61 (ReLU)             (None, 4, 4, 992)            0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 4, 4, 32)             285728    ['re_lu_61[0][0]']
#
#  concatenate_57 (Concatenat  (None, 4, 4, 1024)           0         ['concatenate_56[0][0]',
#  e)                                                                  'conv2d_61[0][0]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['concatenate_57[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    3075      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 9914691 (37.82 MB)
# Trainable params: 9847939 (37.57 MB)
# Non-trainable params: 66752 (260.75 KB)
# __________________________________________________________________________________________________
# None

# %%
DenseModel.fit(datagen(train_paths, train_labels, batch_size=32, epochs=10), steps_per_epoch=len(train_paths)//32, epochs=10)
# Out:
# Epoch 1/10
# 257/257 [==============================] - 623s 2s/step - loss: 1.2757 - accuracy: 0.6350
# Epoch 2/10
# 257/257 [==============================] - 583s 2s/step - loss: 0.5913 - accuracy: 0.7560
# Epoch 3/10
# 257/257 [==============================] - 576s 2s/step - loss: 0.5338 - accuracy: 0.7823
# Epoch 4/10
# 257/257 [==============================] - 578s 2s/step - loss: 0.4145 - accuracy: 0.8299
# Epoch 5/10
# 257/257 [==============================] - 629s 2s/step - loss: 0.3223 - accuracy: 0.8734
# Epoch 6/10
# 257/257 [==============================] - 583s 2s/step - loss: 0.2424 - accuracy: 0.9041
# Epoch 7/10
# 257/257 [==============================] - 631s 2s/step - loss: 0.1721 - accuracy: 0.9385
# Epoch 8/10
# 257/257 [==============================] - 608s 2s/step - loss: 0.1632 - accuracy: 0.9398
# Epoch 9/10
# 257/257 [==============================] - 595s 2s/step - loss: 0.1162 - accuracy: 0.9574
# Epoch 10/10
# 257/257 [==============================] - 598s 2s/step - loss: 0.1047 - accuracy: 0.9601

# %%
# Define Residual Unit block
def residual_unit(input_tensor, filters, strides=(1, 1), activation='relu'):
    shortcut = input_tensor

    x = layers.Conv2D(filters, (3, 3), strides=strides, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)

    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)

    if strides != (1, 1) or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1, 1), strides=strides)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation(activation)(x)

    return x

# Define ResNet model
def ResNet(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = residual_unit(x, 64)
    x = residual_unit(x, 64)
    x = residual_unit(x, 64)

    x = residual_unit(x, 128, strides=(2, 2))
    x = residual_unit(x, 128)
    x = residual_unit(x, 128)

    x = residual_unit(x, 256, strides=(2, 2))
    x = residual_unit(x, 256)
    x = residual_unit(x, 256)

    x = residual_unit(x, 512, strides=(2, 2))
    x = residual_unit(x, 512)
    x = residual_unit(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# %%
# Create ResNet model
ResModel = ResNet(input_shape=(128, 128, 3), num_classes=3)

print(ResModel.summary())

ResModel.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

ResModel.fit(datagen(train_paths, train_labels, batch_size=32, epochs=10), steps_per_epoch=len(train_paths)//32, epochs=10)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d_62 (Conv2D)          (None, 64, 64, 64)           9472      ['input_2[0][0]']
#
#  batch_normalization_62 (Ba  (None, 64, 64, 64)           256       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation (Activation)     (None, 64, 64, 64)           0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)           0         ['activation[0][0]']
#  g2D)
#
#  conv2d_63 (Conv2D)          (None, 32, 32, 64)           36928     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_63 (Ba  (None, 32, 32, 64)           256       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_1[0][0]']
#
#  batch_normalization_64 (Ba  (None, 32, 32, 64)           256       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  add (Add)                   (None, 32, 32, 64)           0         ['batch_normalization_64[0][0]
#                                                                     ',
#                                                                      'max_pooling2d_1[0][0]']
#
#  activation_2 (Activation)   (None, 32, 32, 64)           0         ['add[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_2[0][0]']
#
#  batch_normalization_65 (Ba  (None, 32, 32, 64)           256       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_3[0][0]']
#
#  batch_normalization_66 (Ba  (None, 32, 32, 64)           256       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  add_1 (Add)                 (None, 32, 32, 64)           0         ['batch_normalization_66[0][0]
#                                                                     ',
#                                                                      'activation_2[0][0]']
#
#  activation_4 (Activation)   (None, 32, 32, 64)           0         ['add_1[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_67 (Ba  (None, 32, 32, 64)           256       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_5[0][0]']
#
#  batch_normalization_68 (Ba  (None, 32, 32, 64)           256       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 32, 32, 64)           0         ['batch_normalization_68[0][0]
#                                                                     ',
#                                                                      'activation_4[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 64)           0         ['add_2[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 16, 16, 128)          73856     ['activation_6[0][0]']
#
#  batch_normalization_69 (Ba  (None, 16, 16, 128)          512       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 16, 16, 128)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 16, 16, 128)          147584    ['activation_7[0][0]']
#  conv2d_71 (Conv2D)          (None, 16, 16, 128)          8320      ['activation_6[0][0]']
#
#  batch_normalization_70 (Ba  (None, 16, 16, 128)          512       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  batch_normalization_71 (Ba  (None, 16, 16, 128)          512       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_70[0][0]
#                                                                     ',
#                                                                      'batch_normalization_71[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 16, 16, 128)          0         ['add_3[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 16, 16, 128)          147584    ['activation_8[0][0]']
#
#  batch_normalization_72 (Ba  (None, 16, 16, 128)          512       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 128)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  conv2d_73 (Conv2D)          (None, 16, 16, 128)          147584    ['activation_9[0][0]']
#
#  batch_normalization_73 (Ba  (None, 16, 16, 128)          512       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_73[0][0]
#                                                                     ',
#                                                                      'activation_8[0][0]']
#
#  activation_10 (Activation)  (None, 16, 16, 128)          0         ['add_4[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 16, 16, 128)          147584    ['activation_10[0][0]']
#
#  batch_normalization_74 (Ba  (None, 16, 16, 128)          512       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 16, 16, 128)          147584    ['activation_11[0][0]']
#
#  batch_normalization_75 (Ba  (None, 16, 16, 128)          512       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_75[0][0]
#                                                                     ',
#                                                                      'activation_10[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 128)          0         ['add_5[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 8, 8, 256)            295168    ['activation_12[0][0]']
#
#  batch_normalization_76 (Ba  (None, 8, 8, 256)            1024      ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 8, 8, 256)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 8, 8, 256)            590080    ['activation_13[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 8, 8, 256)            33024     ['activation_12[0][0]']
#
#  batch_normalization_77 (Ba  (None, 8, 8, 256)            1024      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  batch_normalization_78 (Ba  (None, 8, 8, 256)            1024      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 8, 8, 256)            0         ['batch_normalization_77[0][0]
#                                                                     ',
#                                                                      'batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 8, 8, 256)            0         ['add_6[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 8, 8, 256)            590080    ['activation_14[0][0]']
#
#  batch_normalization_79 (Ba  (None, 8, 8, 256)            1024      ['conv2d_79[0][0]']
#  tchNormalization)
#  activation_15 (Activation)  (None, 8, 8, 256)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_80 (Conv2D)          (None, 8, 8, 256)            590080    ['activation_15[0][0]']
#
#  batch_normalization_80 (Ba  (None, 8, 8, 256)            1024      ['conv2d_80[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 8, 8, 256)            0         ['batch_normalization_80[0][0]
#                                                                     ',
#                                                                      'activation_14[0][0]']
#
#  activation_16 (Activation)  (None, 8, 8, 256)            0         ['add_7[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 8, 8, 256)            590080    ['activation_16[0][0]']
#
#  batch_normalization_81 (Ba  (None, 8, 8, 256)            1024      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 8, 8, 256)            0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 8, 8, 256)            590080    ['activation_17[0][0]']
#
#  batch_normalization_82 (Ba  (None, 8, 8, 256)            1024      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 8, 8, 256)            0         ['batch_normalization_82[0][0]
#                                                                     ',
#                                                                      'activation_16[0][0]']
#
#  activation_18 (Activation)  (None, 8, 8, 256)            0         ['add_8[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 4, 4, 512)            1180160   ['activation_18[0][0]']
#
#  batch_normalization_83 (Ba  (None, 4, 4, 512)            2048      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_19[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 4, 4, 512)            131584    ['activation_18[0][0]']
#
#  batch_normalization_84 (Ba  (None, 4, 4, 512)            2048      ['conv2d_84[0][0]']
#  tchNormalization)
#
#  batch_normalization_85 (Ba  (None, 4, 4, 512)            2048      ['conv2d_85[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 4, 4, 512)            0         ['batch_normalization_84[0][0]
#                                                                     ',
#                                                                      'batch_normalization_85[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 4, 4, 512)            0         ['add_9[0][0]']
#
#  conv2d_86 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_20[0][0]']
#
#  batch_normalization_86 (Ba  (None, 4, 4, 512)            2048      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_21[0][0]']
#
#  batch_normalization_87 (Ba  (None, 4, 4, 512)            2048      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 4, 4, 512)            0         ['batch_normalization_87[0][0]
#                                                                     ',
#                                                                      'activation_20[0][0]']
#
#  activation_22 (Activation)  (None, 4, 4, 512)            0         ['add_10[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_22[0][0]']
#
#  batch_normalization_88 (Ba  (None, 4, 4, 512)            2048      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_23[0][0]']
#
#  batch_normalization_89 (Ba  (None, 4, 4, 512)            2048      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 4, 4, 512)            0         ['batch_normalization_89[0][0]
#                                                                     ',
#                                                                      'activation_22[0][0]']
#
#  activation_24 (Activation)  (None, 4, 4, 512)            0         ['add_11[0][0]']
#
#  global_average_pooling2d_1  (None, 512)                  0         ['activation_24[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 3)                    1539      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 17468931 (66.64 MB)
# Trainable params: 17455491 (66.59 MB)
# Non-trainable params: 13440 (52.50 KB)
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# 257/257 [==============================] - 320s 1s/step - loss: 0.5871 - accuracy: 0.7731
# Epoch 2/10
# 257/257 [==============================] - 314s 1s/step - loss: 0.2603 - accuracy: 0.9016
# Epoch 3/10
# 257/257 [==============================] - 328s 1s/step - loss: 0.1544 - accuracy: 0.9444
# Epoch 4/10
# 257/257 [==============================] - 319s 1s/step - loss: 0.1057 - accuracy: 0.9611
# Epoch 5/10
# 257/257 [==============================] - 319s 1s/step - loss: 0.0725 - accuracy: 0.9740
# Epoch 6/10
# 257/257 [==============================] - 325s 1s/step - loss: 0.0620 - accuracy: 0.9787
# Epoch 7/10
# 257/257 [==============================] - 304s 1s/step - loss: 0.0417 - accuracy: 0.9861
# Epoch 8/10
# 257/257 [==============================] - 299s 1s/step - loss: 0.0488 - accuracy: 0.9832
# Epoch 9/10
# 257/257 [==============================] - 330s 1s/step - loss: 0.0332 - accuracy: 0.9888
# Epoch 10/10
# 257/257 [==============================] - 427s 2s/step - loss: 0.0377 - accuracy: 0.9862

# %%
def build_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(16, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

CNN_model = build_model()
CNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_90 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  conv2d_91 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_92 (Conv2D)          (None, 28, 28, 32)        18464
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_2 (Dense)             (None, 16)                401424
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 439331 (1.68 MB)
# Trainable params: 439331 (1.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
CNN_model.fit(datagen(train_paths, train_labels, batch_size=32, epochs=10), steps_per_epoch=len(train_paths)//32, epochs=10)
# Out:
# Epoch 1/10
# 257/257 [==============================] - 72s 278ms/step - loss: 0.5985 - accuracy: 0.7146
# Epoch 2/10
# 257/257 [==============================] - 69s 270ms/step - loss: 0.3632 - accuracy: 0.8443
# Epoch 3/10
# 257/257 [==============================] - 69s 270ms/step - loss: 0.2602 - accuracy: 0.8916
# Epoch 4/10
# 257/257 [==============================] - 70s 272ms/step - loss: 0.1714 - accuracy: 0.9335
# Epoch 5/10
# 257/257 [==============================] - 68s 266ms/step - loss: 0.1150 - accuracy: 0.9591
# Epoch 6/10
# 257/257 [==============================] - 69s 268ms/step - loss: 0.0808 - accuracy: 0.9717
# Epoch 7/10
# 257/257 [==============================] - 69s 267ms/step - loss: 0.0683 - accuracy: 0.9761
# Epoch 8/10
# 257/257 [==============================] - 69s 267ms/step - loss: 0.0570 - accuracy: 0.9813
# Epoch 9/10
# 257/257 [==============================] - 69s 268ms/step - loss: 0.0448 - accuracy: 0.9854
# Epoch 10/10
# 257/257 [==============================] - 69s 268ms/step - loss: 0.0378 - accuracy: 0.9868

# %%
from tensorflow.keras.models import Model

# Ensemble model
def ensemble_model(models, input_shape):
    inputs = layers.Input(shape=input_shape)
    outputs = [model(inputs) for model in models]
    avg = layers.average(outputs)
    ensemble = Model(inputs, avg)
    return ensemble

ensemble_model = ensemble_model([DenseModel, ResModel, CNN_model], input_shape=(128, 128, 3))

# %%
# Save ensemble model
ensemble_model.save('ensemble_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\vijay\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Training graphs
""""
def plot_training(history, title):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.suptitle(title)
    plt.show()

""""

# %%
#plot_training(DenseModel, 'DenseNet Training')
#plot_training(ResModel, 'ResNet Training')
#plot_training(CNN_model, 'CNN Training')

# %%
import matplotlib.pyplot as plt

def plot_training(model, title):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(model.history.history['accuracy'], label='Training Accuracy')
    if 'val_accuracy' in model.history.history:
        plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(model.history.history['loss'], label='Training Loss')
    if 'val_loss' in model.history.history:
        plt.plot(model.history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.suptitle(title)
    plt.show()

# Assuming DenseModel, ResModel, and CNN_model have already been trained using the .fit() method
plot_training(DenseModel, 'DenseNet Training')
plot_training(ResModel, 'ResNet Training')
plot_training(CNN_model, 'CNN Training')

# %%
batch_size = 32
steps = int(len(test_paths)/batch_size)
y_pred = []
y_true = []
for x,y in tqdm(datagen(test_paths, test_labels, batch_size=batch_size, epochs=1), total=steps):
    pred = ensemble_model.predict(x)
    pred = np.argmax(pred, axis=-1)
    for i in decode_label(pred):
        y_pred.append(i)
    for i in decode_label(y):
        y_true.append(i)
# Out:
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]
# 1/1 [==============================] - 3s 3s/step
#   4%|██▉                                                                                | 1/28 [00:03<01:21,  3.03s/it]
# 1/1 [==============================] - 1s 838ms/step
#   7%|█████▉                                                                             | 2/28 [00:04<00:47,  1.82s/it]
# 1/1 [==============================] - 1s 860ms/step
#  11%|████████▉                                                                          | 3/28 [00:05<00:37,  1.50s/it]
# 1/1 [==============================] - 1s 856ms/step
#  14%|███████████▊                                                                       | 4/28 [00:06<00:32,  1.35s/it]
# 1/1 [==============================] - 1s 823ms/step
#  18%|██████████████▊                                                                    | 5/28 [00:07<00:28,  1.24s/it]
# 1/1 [==============================] - 1s 958ms/step
#  21%|█████████████████▊                                                                 | 6/28 [00:08<00:26,  1.21s/it]
# 1/1 [==============================] - 1s 872ms/step
#  25%|████████████████████▊                                                              | 7/28 [00:09<00:25,  1.19s/it]
# 1/1 [==============================] - 1s 871ms/step
#  29%|███████████████████████▋                                                           | 8/28 [00:10<00:23,  1.16s/it]
# 1/1 [==============================] - 1s 933ms/step
#  32%|██████████████████████████▋                                                        | 9/28 [00:11<00:21,  1.16s/it]
# 1/1 [==============================] - 1s 895ms/step
#  36%|█████████████████████████████▎                                                    | 10/28 [00:12<00:20,  1.14s/it]
# 1/1 [==============================] - 1s 949ms/step
#  39%|████████████████████████████████▏                                                 | 11/28 [00:14<00:19,  1.14s/it]
# 1/1 [==============================] - 1s 824ms/step
#  43%|███████████████████████████████████▏                                              | 12/28 [00:15<00:17,  1.11s/it]
# 1/1 [==============================] - 1s 858ms/step
#  46%|██████████████████████████████████████                                            | 13/28 [00:16<00:16,  1.10s/it]
# 1/1 [==============================] - 1s 899ms/step
#  50%|█████████████████████████████████████████                                         | 14/28 [00:17<00:15,  1.10s/it]
# 1/1 [==============================] - 1s 903ms/step
#  54%|███████████████████████████████████████████▉                                      | 15/28 [00:18<00:14,  1.10s/it]
# 1/1 [==============================] - 1s 869ms/step
#  57%|██████████████████████████████████████████████▊                                   | 16/28 [00:19<00:13,  1.11s/it]
# 1/1 [==============================] - 1s 838ms/step
#  61%|█████████████████████████████████████████████████▊                                | 17/28 [00:20<00:12,  1.10s/it]
# 1/1 [==============================] - 1s 872ms/step
#  64%|████████████████████████████████████████████████████▋                             | 18/28 [00:21<00:10,  1.09s/it]
# 1/1 [==============================] - 1s 871ms/step
#  68%|███████████████████████████████████████████████████████▋                          | 19/28 [00:22<00:09,  1.09s/it]
# 1/1 [==============================] - 1s 886ms/step
#  71%|██████████████████████████████████████████████████████████▌                       | 20/28 [00:23<00:08,  1.09s/it]
# 1/1 [==============================] - 1s 916ms/step
#  75%|█████████████████████████████████████████████████████████████▌                    | 21/28 [00:25<00:07,  1.13s/it]
# 1/1 [==============================] - 1s 903ms/step
#  79%|████████████████████████████████████████████████████████████████▍                 | 22/28 [00:26<00:06,  1.13s/it]
# 1/1 [==============================] - 1s 935ms/step
#  82%|███████████████████████████████████████████████████████████████████▎              | 23/28 [00:27<00:05,  1.13s/it]
# 1/1 [==============================] - 1s 820ms/step
#  86%|██████████████████████████████████████████████████████████████████████▎           | 24/28 [00:28<00:04,  1.12s/it]
# 1/1 [==============================] - 1s 822ms/step
#  89%|█████████████████████████████████████████████████████████████████████████▏        | 25/28 [00:29<00:03,  1.10s/it]
# 1/1 [==============================] - 1s 870ms/step
#  93%|████████████████████████████████████████████████████████████████████████████▏     | 26/28 [00:30<00:02,  1.12s/it]
# 1/1 [==============================] - 1s 823ms/step
#  96%|███████████████████████████████████████████████████████████████████████████████   | 27/28 [00:31<00:01,  1.11s/it]
# 1/1 [==============================] - 1s 867ms/step
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:32<00:00,  1.12s/it]
# 1/1 [==============================] - 3s 3s/step
# 29it [00:35,  1.24s/it]

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.95      0.97      0.96       500
#    malignant       0.96      0.95      0.96       400
#       normal       0.88      0.82      0.85        17
#
#     accuracy                           0.96       917
#    macro avg       0.93      0.91      0.92       917
# weighted avg       0.96      0.96      0.96       917

# %%
# Assuming you have defined y_true and y_pred arrays
num_classes = len(np.unique(y_true))
num_classes = 10  # Assuming there are 10 classes in your classification problem

# %%
"""
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):  # Assuming num_classes is the number of classes
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr_micro, tpr_micro, _ = roc_curve(y_true.ravel(), y_pred.ravel())
roc_auc_micro = auc(fpr_micro, tpr_micro)

# Plot ROC curve for each class
plt.figure(figsize=(10, 6))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}), AUC = {roc_auc[i]:.2f}')

# Plot micro-average ROC curve
plt.plot(fpr_micro, tpr_micro, label=f'Micro-average ROC curve, AUC = {roc_auc_micro:.2f}', linestyle='--')

plt.plot([0, 1], [0, 1], 'k--')  # Plot diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
""""
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 9
#       7 roc_auc = dict()
#       8 for i in range(num_classes):  # Assuming num_classes is the number of classes
# ----> 9     fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
#      10     roc_auc[i] = auc(fpr[i], tpr[i])
#      12 # Compute micro-average ROC curve and AUC
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns


# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
